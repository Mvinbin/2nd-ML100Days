# %% [markdown]
# 在分類問題中，若沒有任何限制，決策樹有辦法在訓練時將 training loss 完全降成 0 嗎？
# -->可以，只要把讓每一個terminal node都只有一個observation。
#
# 決策樹只能用在分類問題嗎？還是可以用來解決回歸問題?
# -->deciosn tree可以處理分類與回歸問題，回歸如下圖表示:
# ![image.png](attachment:image.png)
