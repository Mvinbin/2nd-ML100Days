# %%
dat=iris[,1:4]
fit=lm(Petal.Width~.,data=dat)
summary(fit)
plot(fit)
# Out:
# Call:
# lm(formula = Petal.Width ~ ., data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.60959 -0.10134 -0.01089  0.09825  0.60685
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.24031    0.17837  -1.347     0.18
# Sepal.Length -0.20727    0.04751  -4.363 2.41e-05 ***
# Sepal.Width   0.22283    0.04894   4.553 1.10e-05 ***
# Petal.Length  0.52408    0.02449  21.399  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.192 on 146 degrees of freedom
# Multiple R-squared:  0.9379,	Adjusted R-squared:  0.9366
# F-statistic: 734.4 on 3 and 146 DF,  p-value: < 2.2e-16
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
log.dat=iris
log.dat$Species=as.factor(c(rep(1,50),rep(0,100)))
fit.log=glm(Species~Sepal.Length,data=log.dat,family = binomial(link='logit'))
summary(fit.log)
plot(fit.log)
# Out:
# Call:
# glm(formula = Species ~ Sepal.Length, family = binomial(link = "logit"),
#     data = log.dat)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.25787  -0.27914  -0.04605   0.31399   2.14316
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)   27.8285     4.8276   5.765 8.19e-09 ***
# Sepal.Length  -5.1757     0.8934  -5.793 6.90e-09 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 190.954  on 149  degrees of freedom
# Residual deviance:  71.836  on 148  degrees of freedom
# AIC: 75.836
#
# Number of Fisher Scoring iterations: 7
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
