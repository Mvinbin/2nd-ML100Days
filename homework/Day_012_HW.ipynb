# %%
library(data.table)
library(ggplot2)
dat=fread('C:\\Users\\coco40725\\Documents\\GitHub\\2nd-ML100Days\\data\\application_train.csv')
age=abs(dat$DAYS_BIRTH)/365

## 分為 (0, 10], (10, 20], (20, 30], (30, 50], (50, 100] 這五組
customized_age_grp=cut(age,breaks=c(0,10,20,30,50,100))
dat=data.frame(dat,customized_age_grp)
dat
# Out:
# Warning message:
# "package 'data.table' was built under R version 3.5.3"
#        SK_ID_CURR TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR
# 1      100002     1      Cash loans         M           N
# 2      100003     0      Cash loans         F           N
# 3      100004     0      Revolving loans    M           Y
# 4      100006     0      Cash loans         F           N
# 5      100007     0      Cash loans         M           N
# 6      100008     0      Cash loans         M           N
# 7      100009     0      Cash loans         F           Y
# 8      100010     0      Cash loans         M           Y
# 9      100011     0      Cash loans         F           N
# 10     100012     0      Revolving loans    M           N
# 11     100014     0      Cash loans         F           N
# 12     100015     0      Cash loans         F           N
# 13     100016     0      Cash loans         F           N
# 14     100017     0      Cash loans         M           Y
# ...
